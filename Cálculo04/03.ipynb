# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-vidaletec/Programa-o-e-Algoritimos-PA-/blob/main/C%C3%A1lculo04/03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritmos
#  * Cálculo da area
#  # Entrada
#  * Ler lado1
# * Ler lado2
#   # Processamento
#   area = lado1 * lado2
#   # Saída
#
#   * imprimir area

# %%
# Cálculo da área

# Entrada

lado_1 = 5

lado_2 = 4


nome = "Vidal"

# %%
# Processamento

area = lado_1 * lado_2

# %%
# Saída

print (f"Total da área: {area}")
# Out:
# Total da área: 20

# %%
# Tipos Numéricos
idade = 16 # tnt
altura = 1.77 # float
numero_complexo = 2 + 3j # complex

# Tipo Texto
nome = "Vidal" # str

# Tipo Booleano
esta_chovendo = False # bool

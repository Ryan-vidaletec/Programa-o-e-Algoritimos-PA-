# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-vidaletec/Programa-o-e-Algoritimos-PA-/blob/main/27_05PA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jogo menu inteligente

# criar um sistema que funcione ate o usuario escolher sair

#menu

# 1- par/ impar
# 2- postivo negativo
# 3- maior
# 4- sair

opcao = 0
while opcao != 4:
  print("---------------MENU------------------")
  print("-------OPÇÃO 1 - Par ou Impar--------")
  print("---OPÇÃO 2 - Positivo ou Negativo----")
  print("------OPÇÃO 3 - Maior e Menor--------")
  print("----------OPÇÃO 4 - Sair-------------")
  opcao = int(input(" escolha uma das 4 opçoes:  "))

  if opcao == 1:
    numero = int(input("digite um numero par ou impar:  "))
    if opcao % 2 == 0:
      print("seu numero e par")
    else:
      print("seu numero e impar")

  elif opcao == 2:
   numero = int(input(" digite um numero:  "))
   if numero >= 0:
    print("seu numero e postivo")
   else:
    print(" seu numero e negativo")

  elif opcao == 3:
    numero = int(input(" digite um numero:  "))
    numero1 = int(input(" digite um numero:  "))
    if numero > numero1:
      print(f"o numero {numero} e maior que o {numero1}")

    else:
      print(f"o numero{numero1} e maior que o {numero}")

  elif opcao == 4:
    print("voce saiu")
# Out:
# ---------------MENU------------------
# -------OPÇÃO 1 - Par ou Impar--------
# ---OPÇÃO 2 - Positivo ou Negativo----
# ------OPÇÃO 3 - Maior e Menor--------
# ----------OPÇÃO 4 - Sair-------------
#  escolha uma das 4 opçoes:  4
# voce saiu

# %%
from typing import Callable
# Urna eletrônica

# Criar um programa de votação com 3 candidatos

# Votar candidato A, B ou C / Votar Branco / Votar nulo / Encerrar votação

# O sistema deve repetir até encerrar a votação
# Contar votos de cada candidato
# Contar votos brancos e nulos
# Ao encerrar, mostrar:

# Total de votos
# Total de votos por candidato
# Total votos brancos e nulos
# Vencedor da eleição

# Regras extras

# Se houver empate entre candidatos: Mostrar eleição empatada
# Se não houver votos válidos, mostrar: "Nenhum candidato recebeu votos"


Ca = 0
Cb = 0
Cc = 0
Branco = 0
Nulo = 0

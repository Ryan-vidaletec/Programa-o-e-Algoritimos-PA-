# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-vidaletec/Programa-o-e-Algoritimos-PA-/blob/main/lista_tupla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#LISTAS

# %%
# 1.

frutas = ["maçã", "banana", "laranja", "morango"]

print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
# 2.

nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]

print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
# 3.

cores = ["vermelho", "azul", "verde"]

cores[1] = "amarelo"

print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
# 4.

alunos = ["Nicolas", "Wendel", "Pyetra"]

alunos.append("Petros")

print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
# 5.

animais = ["cachorro", "gato", "coelho", "passarinho"]

animais.remove("coelho")

print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
#TUPLAS

# %%
# 1.

meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
# 2.

numeros = (10, 20, 30, 40, 50)

print(numeros[0])
print(numeros[2])
print(numeros[-1])
# Out:
# 10
# 30
# 50

# %%
# 3.

aluno = ("Carlos", 16, "Informática")

print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Carlos
# 16
# Informática

# %%
# 4.

cores = ("vermelho", "azul", "verde")

cores[1] = "amarelo"

print(cores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_801/453079336.py in <cell line: 0>()
#       3 cores = ("vermelho", "azul", "verde")
#       4
# ----> 5 cores[1] = "amarelo"
#       6
#       7 print(cores)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 5.

numeros = (2, 4, 2, 6, 2, 8, 10)

print(numeros.count(2))
# Out:
# 3

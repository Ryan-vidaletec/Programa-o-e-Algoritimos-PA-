# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryan-vidaletec/Programa-o-e-Algoritimos-PA-/blob/main/dic_conj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DICIONÁRIOS

# %%
# 1.

aluno = {
    "nome": "vidal",
    "idade": 16,
    "curso": "Informática"
}

print(aluno)
# Out:
# {'nome': 'vidal', 'idade': 16, 'curso': 'Informática'}

# %%
# 2.

aluno = {
    "nome": "vidal",
    "idade": 16,
    "curso": "Informática"
}

print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])
# Out:
# vidal
# 16
# Informática

# %%
# 3.

produto = {
    "nome": "Caderno",
    "preço": 20,
    "estoque": 50
}

produto["preço"] = 25

print(produto)
# Out:
# {'nome': 'Caderno', 'preço': 25, 'estoque': 50}

# %%
# 4.

aluno = {
    "nome": "vidal",
    "idade": 16
}

aluno["curso"] = "Informática"

print(aluno)
# Out:
# {'nome': 'vidal', 'idade': 16, 'curso': 'Informática'}

# %%
# 5.

filme = {
    "título": "Homem-Aranha",
    "ano": 2021,
    "gênero": "Ação",
    "nota": 9
}

print(filme["título"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Homem-Aranha
# 2021
# Ação
# 9

# %%
#CONJUNTOS

# %%
# 1.

numeros = {1, 2, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 2.

numeros = {1, 2, 2, 3, 3, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 3.

frutas = {"maçã", "banana", "laranja"}

frutas.add("morango")

print(frutas)
# Out:
# {'morango', 'banana', 'maçã', 'laranja'}

# %%
# 4.

cores = {"vermelho", "azul", "verde", "amarelo"}

cores.remove("verde")

print(cores)
# Out:
# {'azul', 'amarelo', 'vermelho'}

# %%
# 5.

nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]

nomes = set(nomes)

print(nomes)
# Out:
# {'Luna', 'Ravi', 'Gael', 'Yris', 'Maitê', 'Theo'}
